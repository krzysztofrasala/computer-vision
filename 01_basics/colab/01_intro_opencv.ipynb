# %% [markdown]
# <a href="https://colab.research.google.com/github/krzysztofrasala/computer-vision/blob/main/01_basics/colab/01_intro_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade opencv-python

# %%
from google.colab.patches import cv2_imshow
import cv2

# %%
img = cv2.imread(filename='view.jpg')
img
# Out:
# array([[[117,  79,  49],
#         [114,  76,  46],
#         [122,  84,  54],
#         ...,
#         [121,  83,  51],
#         [125,  87,  55],
#         [124,  86,  54]],
#
#        [[120,  82,  52],
#         [121,  83,  53],
#         [119,  81,  51],
#         ...,
#         [124,  86,  54],
#         [124,  86,  54],
#         [122,  84,  52]],
#
#        [[122,  84,  54],
#         [122,  84,  54],
#         [118,  80,  50],
#         ...,
#         [124,  87,  53],
#         [121,  84,  50],
#         [121,  84,  50]],
#
#        ...,
#
#        [[ 57,  41,  34],
#         [ 55,  39,  33],
#         [ 50,  34,  28],
#         ...,
#         [ 54,  48,  37],
#         [ 49,  43,  36],
#         [ 42,  38,  33]],
#
#        [[ 55,  38,  29],
#         [ 55,  38,  29],
#         [ 54,  38,  32],
#         ...,
#         [ 49,  38,  30],
#         [ 49,  40,  36],
#         [ 61,  54,  51]],
#
#        [[ 57,  41,  29],
#         [ 58,  41,  32],
#         [ 59,  43,  36],
# ...

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480>

# %%
img.shape
# Out:
# (480, 586, 3)

# %%
cv2.imwrite(filename='view-copy_2.png', img=img)
# Out:
# True

# %%
img = cv2.imread(filename='view.jpg', flags=cv2.IMREAD_GRAYSCALE)
img
# Out:
# array([[74, 71, 79, ..., 78, 82, 81],
#        [77, 78, 76, ..., 81, 81, 79],
#        [79, 79, 75, ..., 81, 78, 78],
#        ...,
#        [41, 39, 34, ..., 45, 42, 37],
#        [37, 37, 38, ..., 37, 40, 54],
#        [39, 40, 43, ..., 50, 53, 47]], dtype=uint8)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=586x480>

# %%
img.shape
# Out:
# (480, 586)
